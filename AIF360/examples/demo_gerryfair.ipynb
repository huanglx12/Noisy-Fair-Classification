# %%
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
import sys
sys.path.append("../")
from aif360.algorithms.inprocessing import GerryFairClassifier
from aif360.algorithms.inprocessing.gerryfair.clean import array_to_tuple
from aif360.algorithms.inprocessing.gerryfair.auditor import Auditor
from aif360.algorithms.preprocessing.optim_preproc_helpers.data_preproc_functions import load_preproc_data_adult
from sklearn import svm
from sklearn import tree
from sklearn.kernel_ridge import KernelRidge
from sklearn import linear_model
from aif360.metrics import BinaryLabelDatasetMetric
from IPython.display import Image
import pickle
import matplotlib.pyplot as plt

# load data set
data_set = load_preproc_data_adult(sub_samp=1000, balance=True)
max_iterations = 500

# %% [markdown]
# **instantiate, fit, and predict**
#
#
# We first demonstrate how to instantiate a `GerryFairClassifier`, `train` it with respect to rich subgroup fairness, and `predict` the label of a new example. We remark that when we set the `print_flag = True` at each iteration of the algorithm we print the error, fairness violation, and violated group size of most recent model. The error is the classification error of the classifier. At each round the Learner tries to find a classifier that minimizes the classification error plus a weighted sum of the fairness disparities on all the groups that the Auditor has found up until that point. By contrast the Auditor tries to find the group at each round with the greatest rich subgroup disparity with respect to the Learner's model. We define `violated group size` as the size (as a fraction of the dataset size) of this group, and the `fairness violation` as the `violated group size` times the difference in the statistical rate (FP or FN rate) on the group vs. the whole population.
#
# In the example below we set `max_iterations=500` which is an order of magnitude less than the time to convergence observed in [the rich subgroup fairness empirical paper](https://arxiv.org/abs/1808.08166), but advise that this can be highly dataset dependent. Our target $\gamma$-disparity is $\gamma = .005$, our statistical rate is false positive rate or `FP`, and our cost-sensitive classification oracle is linear regression (more on that below).

# %%
C = 100
print_flag = True
gamma = .005


fair_model = GerryFairClassifier(C=C, printflag=print_flag, gamma=gamma, fairness_def='FP',
             max_iters=max_iterations, heatmapflag=False)

# fit method
fair_model.fit(data_set, early_termination=True)

# predict method. If threshold in (0, 1) produces binary predictions

dataset_yhat = fair_model.predict(data_set, threshold=False)
# Out:
# iteration: 1, error: 0.261, fairness violation: 0.043624, violated group size: 0.294
# iteration: 2, error: 0.3805, fairness violation: 0.021812, violated group size: 0.294
# iteration: 3, error: 0.4203333333333333, fairness violation: 0.014541333333333335, violated group size: 0.294
# iteration: 4, error: 0.44025, fairness violation: 0.010906, violated group size: 0.294
# iteration: 5, error: 0.45220000000000005, fairness violation: 0.008724800000000003, violated group size: 0.294
# iteration: 6, error: 0.46016666666666667, fairness violation: 0.0072706666666666675, violated group size: 0.294
# iteration: 7, error: 0.46585714285714297, fairness violation: 0.006232000000000009, violated group size: 0.294
# iteration: 8, error: 0.470125, fairness violation: 0.005453000000000002, violated group size: 0.206
# iteration: 9, error: 0.47344444444444456, fairness violation: 0.004847111111111113, violated group size: 0.206
# iteration: 10, error: 0.4761000000000001, fairness violation: 0.004362400000000001, violated group size: 0.206
# iteration: 11, error: 0.4782727272727271, fairness violation: 0.003965818181818183, violated group size: 0.294
# iteration: 12, error: 0.4800833333333333, fairness violation: 0.0036353333333333337, violated group size: 0.294
# iteration: 13, error: 0.4816153846153847, fairness violation: 0.003355692307692308, violated group size: 0.294
# iteration: 14, error: 0.48292857142857143, fairness violation: 0.0031160000000000024, violated group size: 0.294
# iteration: 15, error: 0.4840666666666667, fairness violation: 0.002908266666666669, violated group size: 0.294
# iteration: 16, error: 0.4850625, fairness violation: 0.002726500000000001, violated group size: 0.206
# iteration: 17, error: 0.48594117647058827, fairness violation: 0.0025661176470588246, violated group size: 0.206
# iteration: 18, error: 0.4867222222222223, fairness violation: 0.002423555555555557, violated group size: 0.206
# iteration: 19, error: 0.48742105263157903, fairness violation: 0.002296000000000001, violated group size: 0.206
# iteration: 20, error: 0.4880499999999999, fairness violation: 0.0021812000000000008, violated group size: 0.206
# iteration: 21, error: 0.4886190476190477, fairness violation: 0.0020773333333333342, violated group size: 0.294
# iteration: 22, error: 0.4891363636363638, fairness violation: 0.0019829090909090916, violated group size: 0.294
# iteration: 23, error: 0.4896086956521741, fairness violation: 0.0018966956521739142, violated group size: 0.206
# iteration: 24, error: 0.4900416666666667, fairness violation: 0.0018176666666666673, violated group size: 0.206
# iteration: 25, error: 0.4904400000000001, fairness violation: 0.0017449600000000007, violated group size: 0.206
# iteration: 26, error: 0.49080769230769233, fairness violation: 0.001677846153846154, violated group size: 0.294
# iteration: 27, error: 0.4911481481481483, fairness violation: 0.001615703703703704, violated group size: 0.294
# iteration: 28, error: 0.4914642857142856, fairness violation: 0.0015580000000000023, violated group size: 0.294
# iteration: 29, error: 0.49175862068965503, fairness violation: 0.001504275862068966, violated group size: 0.206
# iteration: 30, error: 0.4920333333333334, fairness violation: 0.001454133333333334, violated group size: 0.294
# iteration: 31, error: 0.49229032258064526, fairness violation: 0.001407225806451613, violated group size: 0.206
# iteration: 32, error: 0.49253125, fairness violation: 0.0013632500000000005, violated group size: 0.206
# iteration: 33, error: 0.4927575757575756, fairness violation: 0.0013219393939393944, violated group size: 0.206
# iteration: 34, error: 0.49297058823529416, fairness violation: 0.001283058823529412, violated group size: 0.294
# iteration: 35, error: 0.4931714285714286, fairness violation: 0.0012464000000000006, violated group size: 0.294
# iteration: 36, error: 0.493361111111111, fairness violation: 0.0012117777777777782, violated group size: 0.206
# iteration: 37, error: 0.49354054054054064, fairness violation: 0.0011790270270270276, violated group size: 0.294
# iteration: 38, error: 0.4937105263157894, fairness violation: 0.0011480000000000006, violated group size: 0.206
# iteration: 39, error: 0.49387179487179494, fairness violation: 0.001118564102564103, violated group size: 0.294
# iteration: 40, error: 0.49402499999999994, fairness violation: 0.0010906000000000004, violated group size: 0.206
# iteration: 41, error: 0.4941707317073172, fairness violation: 0.0010640000000000005, violated group size: 0.206
# iteration: 42, error: 0.4943095238095238, fairness violation: 0.0010386666666666671, violated group size: 0.294
# iteration: 43, error: 0.4944418604651163, fairness violation: 0.0010145116279069767, violated group size: 0.206
# iteration: 44, error: 0.4945681818181817, fairness violation: 0.0009914545454545458, violated group size: 0.294
# iteration: 45, error: 0.4946888888888889, fairness violation: 0.0009694222222222225, violated group size: 0.206
# iteration: 46, error: 0.4948043478260869, fairness violation: 0.0009483478260869568, violated group size: 0.206
# iteration: 47, error: 0.4949148936170214, fairness violation: 0.0009281702127659578, violated group size: 0.294
# iteration: 48, error: 0.4950208333333333, fairness violation: 0.0009088333333333334, violated group size: 0.294
# iteration: 49, error: 0.4951224489795917, fairness violation: 0.0008902857142857146, violated group size: 0.294
# iteration: 50, error: 0.49522000000000016, fairness violation: 0.0008724799999999999, violated group size: 0.206
# iteration: 51, error: 0.49531372549019614, fairness violation: 0.000855372549019608, violated group size: 0.206
# iteration: 52, error: 0.495403846153846, fairness violation: 0.000838923076923077, violated group size: 0.294
# iteration: 53, error: 0.49549056603773595, fairness violation: 0.0008230943396226416, violated group size: 0.206
# iteration: 54, error: 0.4953888888888888, fairness violation: 0.0008307407407407406, violated group size: 0.206
# iteration: 55, error: 0.49547272727272734, fairness violation: 0.0008156363636363635, violated group size: 0.206
# iteration: 56, error: 0.4955535714285715, fairness violation: 0.0008010714285714288, violated group size: 0.294
# iteration: 57, error: 0.49545614035087715, fairness violation: 0.0008087017543859651, violated group size: 0.294
# iteration: 58, error: 0.49553448275862066, fairness violation: 0.0007947586206896553, violated group size: 0.206
# iteration: 59, error: 0.4956101694915253, fairness violation: 0.0007812881355932202, violated group size: 0.206
# iteration: 60, error: 0.49551666666666655, fairness violation: 0.0007888666666666668, violated group size: 0.294
# iteration: 61, error: 0.49542622950819676, fairness violation: 0.0007961967213114756, violated group size: 0.206
# iteration: 62, error: 0.49533870967741944, fairness violation: 0.000803290322580645, violated group size: 0.206
# iteration: 63, error: 0.4952539682539683, fairness violation: 0.00081015873015873, violated group size: 0.206
# iteration: 64, error: 0.495171875, fairness violation: 0.0008168125000000002, violated group size: 0.294
# iteration: 65, error: 0.4950923076923077, fairness violation: 0.0008232615384615389, violated group size: 0.294
# iteration: 66, error: 0.4950151515151514, fairness violation: 0.0008295151515151522, violated group size: 0.294
# iteration: 67, error: 0.4940895522388059, fairness violation: 0.0009093731343283581, violated group size: 0.206
# iteration: 68, error: 0.49279411764705877, fairness violation: 0.001029294117647059, violated group size: 0.294
# iteration: 69, error: 0.49153623188405804, fairness violation: 0.0011457391304347826, violated group size: 0.206
# iteration: 70, error: 0.49031428571428576, fairness violation: 0.0012588571428571427, violated group size: 0.206
# iteration: 71, error: 0.4891267605633802, fairness violation: 0.0013687887323943664, violated group size: 0.206
# iteration: 72, error: 0.48797222222222225, fairness violation: 0.001475666666666667, violated group size: 0.206
# iteration: 73, error: 0.4868493150684931, fairness violation: 0.0017647671232876715, violated group size: 0.239
# iteration: 74, error: 0.4857567567567567, fairness violation: 0.0018830270270270278, violated group size: 0.261
# iteration: 75, error: 0.4846933333333333, fairness violation: 0.0019981333333333336, violated group size: 0.239
# iteration: 76, error: 0.48365789473684195, fairness violation: 0.00211021052631579, violated group size: 0.261
# iteration: 77, error: 0.48264935064935066, fairness violation: 0.0022193766233766245, violated group size: 0.261
# iteration: 78, error: 0.4816666666666667, fairness violation: 0.002325743589743591, violated group size: 0.261
# iteration: 79, error: 0.4807088607594937, fairness violation: 0.0024294177215189883, violated group size: 0.261
# iteration: 80, error: 0.4797750000000001, fairness violation: 0.002530500000000001, violated group size: 0.261
# iteration: 81, error: 0.47886419753086423, fairness violation: 0.002629086419753088, violated group size: 0.261
# iteration: 82, error: 0.4779756097560976, fairness violation: 0.0027252682926829277, violated group size: 0.239
# iteration: 83, error: 0.47710843373493966, fairness violation: 0.0028191325301204825, violated group size: 0.239
# iteration: 84, error: 0.47626190476190466, fairness violation: 0.002910761904761907, violated group size: 0.261
# iteration: 85, error: 0.47543529411764707, fairness violation: 0.0030002352941176486, violated group size: 0.239
# iteration: 86, error: 0.4746279069767441, fairness violation: 0.003087627906976746, violated group size: 0.239
# iteration: 87, error: 0.4738390804597702, fairness violation: 0.0031730114942528755, violated group size: 0.261
# iteration: 88, error: 0.4730113636363636, fairness violation: 0.003244590909090911, violated group size: 0.261
# iteration: 89, error: 0.47220224719101134, fairness violation: 0.0033145617977528114, violated group size: 0.261
# iteration: 90, error: 0.47141111111111106, fairness violation: 0.00338297777777778, violated group size: 0.261
# iteration: 91, error: 0.47061538461538466, fairness violation: 0.003096263736263738, violated group size: 0.206
# iteration: 92, error: 0.469858695652174, fairness violation: 0.00317008695652174, violated group size: 0.206
# iteration: 93, error: 0.4691182795698924, fairness violation: 0.003242322580645163, violated group size: 0.294
# iteration: 94, error: 0.46842553191489367, fairness violation: 0.003304255319148937, violated group size: 0.206
# iteration: 95, error: 0.4676947368421053, fairness violation: 0.0033735578947368433, violated group size: 0.294
# iteration: 96, error: 0.46697916666666667, fairness violation: 0.0034414166666666703, violated group size: 0.294
# iteration: 97, error: 0.4662783505154639, fairness violation: 0.0035078762886597953, violated group size: 0.206
# iteration: 98, error: 0.4655918367346939, fairness violation: 0.0035729795918367363, violated group size: 0.206
# iteration: 99, error: 0.46491919191919184, fairness violation: 0.003636767676767679, violated group size: 0.294
# iteration: 100, error: 0.46426, fairness violation: 0.0036992800000000023, violated group size: 0.206
# iteration: 101, error: 0.4636138613861387, fairness violation: 0.0037605544554455464, violated group size: 0.206
# iteration: 102, error: 0.46298039215686276, fairness violation: 0.0038206274509803937, violated group size: 0.206
# iteration: 103, error: 0.46235922330097096, fairness violation: 0.003879533980582526, violated group size: 0.206
# iteration: 104, error: 0.4617499999999999, fairness violation: 0.003937307692307695, violated group size: 0.206
# iteration: 105, error: 0.46115238095238087, fairness violation: 0.003993980952380956, violated group size: 0.294
# iteration: 106, error: 0.4605660377358491, fairness violation: 0.004049584905660382, violated group size: 0.294
# iteration: 107, error: 0.4599906542056075, fairness violation: 0.004104149532710283, violated group size: 0.206
# iteration: 108, error: 0.45942592592592585, fairness violation: 0.004157703703703707, violated group size: 0.294
# iteration: 109, error: 0.45887155963302756, fairness violation: 0.004210275229357801, violated group size: 0.206
# iteration: 110, error: 0.45832727272727264, fairness violation: 0.004261890909090913, violated group size: 0.294
# iteration: 111, error: 0.4577927927927927, fairness violation: 0.004312576576576579, violated group size: 0.206
# iteration: 112, error: 0.4572678571428571, fairness violation: 0.004362357142857145, violated group size: 0.206
# iteration: 113, error: 0.45675221238938046, fairness violation: 0.004411256637168144, violated group size: 0.206
# iteration: 114, error: 0.4562456140350877, fairness violation: 0.004459298245614037, violated group size: 0.206
# iteration: 115, error: 0.4557478260869565, fairness violation: 0.0045065043478260906, violated group size: 0.294
# iteration: 116, error: 0.4552586206896551, fairness violation: 0.004552896551724143, violated group size: 0.294
# iteration: 117, error: 0.4547777777777777, fairness violation: 0.00459849572649573, violated group size: 0.294
# iteration: 118, error: 0.4543050847457626, fairness violation: 0.00464332203389831, violated group size: 0.294
# iteration: 119, error: 0.4538403361344537, fairness violation: 0.004687394957983197, violated group size: 0.206
# iteration: 120, error: 0.45338333333333336, fairness violation: 0.0047307333333333375, violated group size: 0.294
# iteration: 121, error: 0.45293388429752063, fairness violation: 0.004773355371900831, violated group size: 0.206
# iteration: 122, error: 0.4524918032786884, fairness violation: 0.004815278688524596, violated group size: 0.294
# iteration: 123, error: 0.4520569105691057, fairness violation: 0.004856520325203256, violated group size: 0.294
# iteration: 124, error: 0.45162903225806444, fairness violation: 0.004897096774193554, violated group size: 0.294
# iteration: 125, error: 0.45120800000000005, fairness violation: 0.004937024000000004, violated group size: 0.206
# iteration: 126, error: 0.45079365079365086, fairness violation: 0.004976317460317464, violated group size: 0.206
# iteration: 127, error: 0.45038582677165345, fairness violation: 0.005014992125984255, violated group size: 0.206
# iteration: 128, error: 0.449984375, fairness violation: 0.0050530625000000055, violated group size: 0.294
# iteration: 129, error: 0.44958914728682164, fairness violation: 0.00509054263565892, violated group size: 0.206
# iteration: 130, error: 0.4492, fairness violation: 0.005127446153846158, violated group size: 0.294
# iteration: 131, error: 0.44883206106870227, fairness violation: 0.005163786259541989, violated group size: 0.206
# iteration: 132, error: 0.4485075757575757, fairness violation: 0.005193333333333337, violated group size: 0.294
# iteration: 133, error: 0.4481879699248119, fairness violation: 0.005222436090225568, violated group size: 0.206
# iteration: 134, error: 0.44787313432835824, fairness violation: 0.005251104477611944, violated group size: 0.294
# iteration: 135, error: 0.4477629629629629, fairness violation: 0.005257985185185188, violated group size: 0.206
# iteration: 136, error: 0.44807352941176465, fairness violation: 0.005228411764705885, violated group size: 0.206
# iteration: 137, error: 0.4483795620437956, fairness violation: 0.0051992700729927045, violated group size: 0.206
# iteration: 138, error: 0.44868115942028985, fairness violation: 0.005170550724637684, violated group size: 0.206
# iteration: 139, error: 0.448978417266187, fairness violation: 0.005142244604316549, violated group size: 0.206
# iteration: 140, error: 0.4492714285714286, fairness violation: 0.00511434285714286, violated group size: 0.206
# iteration: 141, error: 0.44963120567375886, fairness violation: 0.005078070921985819, violated group size: 0.206
# iteration: 142, error: 0.44998591549295774, fairness violation: 0.005042309859154933, violated group size: 0.294
# iteration: 143, error: 0.4503356643356643, fairness violation: 0.005007048951048956, violated group size: 0.294
# iteration: 144, error: 0.4506805555555555, fairness violation: 0.004972277777777782, violated group size: 0.206
# iteration: 145, error: 0.4510206896551725, fairness violation: 0.004937986206896555, violated group size: 0.206
# iteration: 146, error: 0.4513561643835616, fairness violation: 0.004904164383561648, violated group size: 0.294
# iteration: 147, error: 0.4516870748299319, fairness violation: 0.0048708027210884386, violated group size: 0.206
# iteration: 148, error: 0.45201351351351354, fairness violation: 0.004837891891891895, violated group size: 0.206
# iteration: 149, error: 0.4523355704697988, fairness violation: 0.0048054228187919485, violated group size: 0.206
# iteration: 150, error: 0.45265333333333335, fairness violation: 0.004773386666666669, violated group size: 0.206
# iteration: 151, error: 0.4529668874172185, fairness violation: 0.0047417748344370896, violated group size: 0.294
# iteration: 152, error: 0.45327631578947364, fairness violation: 0.004710578947368425, violated group size: 0.206
# iteration: 153, error: 0.4535816993464052, fairness violation: 0.0046797908496732064, violated group size: 0.294
# iteration: 154, error: 0.4538831168831169, fairness violation: 0.0046494025974026, violated group size: 0.206
# iteration: 155, error: 0.4541806451612903, fairness violation: 0.0046194064516129054, violated group size: 0.206
# iteration: 156, error: 0.454474358974359, fairness violation: 0.004589794871794876, violated group size: 0.294
# iteration: 157, error: 0.4547643312101911, fairness violation: 0.004560560509554143, violated group size: 0.206
# iteration: 158, error: 0.45505063291139236, fairness violation: 0.004531696202531649, violated group size: 0.294
# iteration: 159, error: 0.4553333333333333, fairness violation: 0.004503194968553463, violated group size: 0.294
# iteration: 160, error: 0.4556125000000001, fairness violation: 0.004475050000000004, violated group size: 0.294
# iteration: 161, error: 0.45588819875776404, fairness violation: 0.004447254658385097, violated group size: 0.206
# iteration: 162, error: 0.45616049382716056, fairness violation: 0.004419802469135806, violated group size: 0.294
# iteration: 163, error: 0.45642944785276074, fairness violation: 0.004392687116564421, violated group size: 0.294
# iteration: 164, error: 0.45669512195121953, fairness violation: 0.004365902439024393, violated group size: 0.206
# iteration: 165, error: 0.45695757575757573, fairness violation: 0.0043394424242424266, violated group size: 0.294
# iteration: 166, error: 0.4572168674698796, fairness violation: 0.004313301204819281, violated group size: 0.294
# iteration: 167, error: 0.4574730538922156, fairness violation: 0.004287473053892217, violated group size: 0.206
# iteration: 168, error: 0.4577261904761904, fairness violation: 0.004261952380952383, violated group size: 0.206
# iteration: 169, error: 0.4579763313609467, fairness violation: 0.004236733727810653, violated group size: 0.206
# iteration: 170, error: 0.45822352941176475, fairness violation: 0.004211811764705884, violated group size: 0.206
# iteration: 171, error: 0.4584678362573099, fairness violation: 0.004187181286549709, violated group size: 0.206
# iteration: 172, error: 0.4587093023255813, fairness violation: 0.004162837209302328, violated group size: 0.206
# iteration: 173, error: 0.4589479768786126, fairness violation: 0.0041387745664739906, violated group size: 0.294
# iteration: 174, error: 0.4591264367816091, fairness violation: 0.004122091954022991, violated group size: 0.294
# iteration: 175, error: 0.45936000000000005, fairness violation: 0.004098537142857145, violated group size: 0.206
# iteration: 176, error: 0.45959090909090905, fairness violation: 0.004075250000000003, violated group size: 0.294
# iteration: 177, error: 0.4597627118644067, fairness violation: 0.004059209039548024, violated group size: 0.206
# iteration: 178, error: 0.4599887640449438, fairness violation: 0.0040364044943820235, violated group size: 0.206
# iteration: 179, error: 0.4601564245810056, fairness violation: 0.004020759776536314, violated group size: 0.206
# iteration: 180, error: 0.4603777777777776, fairness violation: 0.003998422222222224, violated group size: 0.206
# iteration: 181, error: 0.4605414364640885, fairness violation: 0.0039831602209944765, violated group size: 0.206
# iteration: 182, error: 0.4607032967032967, fairness violation: 0.003968065934065936, violated group size: 0.206
# iteration: 183, error: 0.4609180327868853, fairness violation: 0.003946382513661205, violated group size: 0.206
# iteration: 184, error: 0.4610760869565218, fairness violation: 0.003931652173913046, violated group size: 0.294
# iteration: 185, error: 0.4612324324324324, fairness violation: 0.003917081081081083, violated group size: 0.206
# iteration: 186, error: 0.4613870967741935, fairness violation: 0.003902666666666669, violated group size: 0.206
# iteration: 187, error: 0.4615401069518716, fairness violation: 0.0038884064171123027, violated group size: 0.294
# iteration: 188, error: 0.4616914893617021, fairness violation: 0.0038742978723404274, violated group size: 0.206
# iteration: 189, error: 0.46184126984126983, fairness violation: 0.003860338624338626, violated group size: 0.206
# iteration: 190, error: 0.46198947368421056, fairness violation: 0.003846526315789476, violated group size: 0.294
# iteration: 191, error: 0.46213612565445034, fairness violation: 0.0038328586387434567, violated group size: 0.206
# iteration: 192, error: 0.4622812499999999, fairness violation: 0.003819333333333335, violated group size: 0.206
# iteration: 193, error: 0.4624248704663213, fairness violation: 0.0038059481865284988, violated group size: 0.206
# iteration: 194, error: 0.4622731958762886, fairness violation: 0.0038181855670103098, violated group size: 0.206
# iteration: 195, error: 0.4624153846153847, fairness violation: 0.0038049435897435906, violated group size: 0.294
# iteration: 196, error: 0.46255612244897953, fairness violation: 0.003791836734693879, violated group size: 0.206
# iteration: 197, error: 0.46269543147208114, fairness violation: 0.003778862944162438, violated group size: 0.206
# iteration: 198, error: 0.4628333333333333, fairness violation: 0.0037660202020202045, violated group size: 0.294
# iteration: 199, error: 0.46296984924623114, fairness violation: 0.003753306532663318, violated group size: 0.206
# iteration: 200, error: 0.46281999999999995, fairness violation: 0.003765440000000002, violated group size: 0.206
# iteration: 201, error: 0.46295522388059696, fairness violation: 0.003752855721393036, violated group size: 0.206
# iteration: 202, error: 0.46267326732673275, fairness violation: 0.003779148514851487, violated group size: 0.206
# iteration: 203, error: 0.462807881773399, fairness violation: 0.003766620689655174, violated group size: 0.206
# iteration: 204, error: 0.46252941176470597, fairness violation: 0.0037925882352941196, violated group size: 0.294
# iteration: 205, error: 0.4623853658536586, fairness violation: 0.0038042341463414646, violated group size: 0.206
# iteration: 206, error: 0.4622427184466019, fairness violation: 0.0038157669902912634, violated group size: 0.294
# iteration: 207, error: 0.4621014492753622, fairness violation: 0.0038271884057971034, violated group size: 0.206
# iteration: 208, error: 0.46196153846153853, fairness violation: 0.0038385000000000016, violated group size: 0.206
# iteration: 209, error: 0.46169377990430616, fairness violation: 0.003863502392344499, violated group size: 0.206
# iteration: 210, error: 0.46142857142857135, fairness violation: 0.0038882666666666685, violated group size: 0.206
# iteration: 211, error: 0.4611658767772511, fairness violation: 0.003912796208530808, violated group size: 0.206
# iteration: 212, error: 0.4610330188679245, fairness violation: 0.0039234905660377375, violated group size: 0.206
# iteration: 213, error: 0.4607746478873238, fairness violation: 0.0039476244131455415, violated group size: 0.206
# iteration: 214, error: 0.4605186915887851, fairness violation: 0.003971532710280376, violated group size: 0.294
# iteration: 215, error: 0.4602651162790698, fairness violation: 0.003995218604651165, violated group size: 0.294
# iteration: 216, error: 0.4600138888888888, fairness violation: 0.0040186851851851885, violated group size: 0.294
# iteration: 217, error: 0.45976497695852536, fairness violation: 0.00404193548387097, violated group size: 0.206
# iteration: 218, error: 0.4595183486238531, fairness violation: 0.004064972477064223, violated group size: 0.206
# iteration: 219, error: 0.4592739726027398, fairness violation: 0.004087799086757993, violated group size: 0.206
# iteration: 220, error: 0.45903181818181815, fairness violation: 0.004110418181818184, violated group size: 0.294
# iteration: 221, error: 0.4587918552036199, fairness violation: 0.004132832579185523, violated group size: 0.206
# iteration: 222, error: 0.458554054054054, fairness violation: 0.004155045045045047, violated group size: 0.206
# iteration: 223, error: 0.4583183856502243, fairness violation: 0.004177058295964128, violated group size: 0.206
# iteration: 224, error: 0.4580848214285713, fairness violation: 0.004198875000000002, violated group size: 0.206
# iteration: 225, error: 0.4578533333333333, fairness violation: 0.004220497777777779, violated group size: 0.206
# iteration: 226, error: 0.45762389380530977, fairness violation: 0.004241929203539826, violated group size: 0.206
# iteration: 227, error: 0.4573964757709251, fairness violation: 0.004263171806167402, violated group size: 0.206
# iteration: 228, error: 0.457171052631579, fairness violation: 0.004284228070175441, violated group size: 0.206
# iteration: 229, error: 0.456947598253275, fairness violation: 0.004305100436681224, violated group size: 0.206
# iteration: 230, error: 0.4567260869565217, fairness violation: 0.004325791304347828, violated group size: 0.294
# iteration: 231, error: 0.4565064935064934, fairness violation: 0.004346303030303031, violated group size: 0.206
# iteration: 232, error: 0.45628879310344833, fairness violation: 0.004366637931034484, violated group size: 0.294
# iteration: 233, error: 0.4560729613733906, fairness violation: 0.004386798283261804, violated group size: 0.294
# iteration: 234, error: 0.4558589743589744, fairness violation: 0.004406786324786328, violated group size: 0.294
# iteration: 235, error: 0.4556468085106384, fairness violation: 0.00442660425531915, violated group size: 0.206
# iteration: 236, error: 0.4554364406779661, fairness violation: 0.004446254237288137, violated group size: 0.294
# iteration: 237, error: 0.45522784810126576, fairness violation: 0.004465738396624474, violated group size: 0.206
# iteration: 238, error: 0.45502100840336135, fairness violation: 0.004485058823529414, violated group size: 0.294
# iteration: 239, error: 0.45481589958158997, fairness violation: 0.00450421757322176, violated group size: 0.294
# iteration: 240, error: 0.45461250000000003, fairness violation: 0.004523216666666669, violated group size: 0.206
# iteration: 241, error: 0.45441078838174276, fairness violation: 0.004542058091286309, violated group size: 0.294
# iteration: 242, error: 0.4542107438016528, fairness violation: 0.004560743801652893, violated group size: 0.206
# iteration: 243, error: 0.4540123456790122, fairness violation: 0.004579275720164609, violated group size: 0.206
# iteration: 244, error: 0.4538155737704918, fairness violation: 0.004597655737704919, violated group size: 0.206
# iteration: 245, error: 0.4536204081632652, fairness violation: 0.004615885714285715, violated group size: 0.206
# iteration: 246, error: 0.4534268292682927, fairness violation: 0.004633967479674797, violated group size: 0.206
# iteration: 247, error: 0.4532348178137652, fairness violation: 0.004651902834008098, violated group size: 0.206
# iteration: 248, error: 0.45304435483870964, fairness violation: 0.004669693548387098, violated group size: 0.206
# iteration: 249, error: 0.45285542168674703, fairness violation: 0.0046873413654618485, violated group size: 0.294
# iteration: 250, error: 0.45266800000000007, fairness violation: 0.004704848000000001, violated group size: 0.294
# iteration: 251, error: 0.45248207171314747, fairness violation: 0.004722215139442231, violated group size: 0.206
# iteration: 252, error: 0.4522976190476191, fairness violation: 0.004739444444444444, violated group size: 0.206
# iteration: 253, error: 0.4521146245059288, fairness violation: 0.004756537549407114, violated group size: 0.294
# iteration: 254, error: 0.4519330708661418, fairness violation: 0.004773496062992126, violated group size: 0.294
# iteration: 255, error: 0.4517529411764706, fairness violation: 0.004790321568627453, violated group size: 0.294
# iteration: 256, error: 0.45157421875, fairness violation: 0.004807015625000003, violated group size: 0.294
# iteration: 257, error: 0.4513968871595331, fairness violation: 0.004823579766536966, violated group size: 0.294
# iteration: 258, error: 0.4512209302325582, fairness violation: 0.004840015503875969, violated group size: 0.206
# iteration: 259, error: 0.451046332046332, fairness violation: 0.004856324324324325, violated group size: 0.206
# iteration: 260, error: 0.45087307692307677, fairness violation: 0.004872507692307693, violated group size: 0.206
# iteration: 261, error: 0.4507011494252873, fairness violation: 0.004888567049808432, violated group size: 0.294
# iteration: 262, error: 0.4505305343511451, fairness violation: 0.004904503816793895, violated group size: 0.294
# iteration: 263, error: 0.4503612167300379, fairness violation: 0.004920319391634983, violated group size: 0.294
# iteration: 264, error: 0.4501931818181818, fairness violation: 0.004936015151515153, violated group size: 0.206
# iteration: 265, error: 0.45002641509433966, fairness violation: 0.004951592452830191, violated group size: 0.294
# iteration: 266, error: 0.4498609022556391, fairness violation: 0.004967052631578949, violated group size: 0.294
# iteration: 267, error: 0.4496966292134832, fairness violation: 0.004982397003745319, violated group size: 0.206
# iteration: 268, error: 0.4495261194029851, fairness violation: 0.004997626865671644, violated group size: 0.294
# iteration: 269, error: 0.449364312267658, fairness violation: 0.005012743494423792, violated group size: 0.206
# iteration: 270, error: 0.44920370370370377, fairness violation: 0.005027748148148148, violated group size: 0.206
# iteration: 271, error: 0.44904428044280437, fairness violation: 0.005042642066420664, violated group size: 0.294
# iteration: 272, error: 0.4488860294117647, fairness violation: 0.005057426470588235, violated group size: 0.206
# iteration: 273, error: 0.44872893772893774, fairness violation: 0.0050721025641025635, violated group size: 0.206
# iteration: 274, error: 0.44857299270073003, fairness violation: 0.005086671532846715, violated group size: 0.206
# iteration: 275, error: 0.44841818181818177, fairness violation: 0.005101134545454546, violated group size: 0.206
# iteration: 276, error: 0.4482644927536232, fairness violation: 0.005115492753623189, violated group size: 0.294
# iteration: 277, error: 0.44811191335740075, fairness violation: 0.005129747292418773, violated group size: 0.294
# iteration: 278, error: 0.44805755395683444, fairness violation: 0.005133525179856116, violated group size: 0.294
# iteration: 279, error: 0.44800358422939074, fairness violation: 0.005137275985663085, violated group size: 0.294
# iteration: 280, error: 0.4481892857142858, fairness violation: 0.005118928571428572, violated group size: 0.206
# iteration: 281, error: 0.4483380782918149, fairness violation: 0.0051051103202846984, violated group size: 0.294
# iteration: 282, error: 0.4484858156028369, fairness violation: 0.005091390070921985, violated group size: 0.206
# iteration: 283, error: 0.44863250883392225, fairness violation: 0.005077766784452299, violated group size: 0.294
# iteration: 284, error: 0.44877816901408446, fairness violation: 0.0050642394366197194, violated group size: 0.206
# iteration: 285, error: 0.4489228070175437, fairness violation: 0.0050508070175438605, violated group size: 0.206
# iteration: 286, error: 0.4490664335664336, fairness violation: 0.005037468531468532, violated group size: 0.294
# iteration: 287, error: 0.44924390243902435, fairness violation: 0.005019916376306621, violated group size: 0.294
# iteration: 288, error: 0.449420138888889, fairness violation: 0.005002486111111111, violated group size: 0.206
# iteration: 289, error: 0.44959515570934244, fairness violation: 0.004985176470588237, violated group size: 0.294
# iteration: 290, error: 0.4497689655172413, fairness violation: 0.004967986206896552, violated group size: 0.206
# iteration: 291, error: 0.4499415807560137, fairness violation: 0.004950914089347078, violated group size: 0.206
# iteration: 292, error: 0.45011301369863016, fairness violation: 0.004933958904109589, violated group size: 0.206
# iteration: 293, error: 0.45028327645051186, fairness violation: 0.004917119453924915, violated group size: 0.294
# iteration: 294, error: 0.4504523809523811, fairness violation: 0.004900394557823129, violated group size: 0.206
# iteration: 295, error: 0.45062033898305076, fairness violation: 0.004883783050847458, violated group size: 0.294
# iteration: 296, error: 0.4507871621621621, fairness violation: 0.004867283783783784, violated group size: 0.294
# iteration: 297, error: 0.45095286195286194, fairness violation: 0.004850895622895623, violated group size: 0.206
# iteration: 298, error: 0.4510838926174497, fairness violation: 0.004838765100671142, violated group size: 0.294
# iteration: 299, error: 0.45124749163879596, fairness violation: 0.004822581939799332, violated group size: 0.294
# iteration: 300, error: 0.4514099999999999, fairness violation: 0.004806506666666667, violated group size: 0.206
# iteration: 301, error: 0.4515714285714287, fairness violation: 0.004790538205980067, violated group size: 0.206
# iteration: 302, error: 0.45173178807947023, fairness violation: 0.004774675496688742, violated group size: 0.294
# iteration: 303, error: 0.451891089108911, fairness violation: 0.004758917491749175, violated group size: 0.294
# iteration: 304, error: 0.45201644736842106, fairness violation: 0.004747328947368421, violated group size: 0.206
# iteration: 305, error: 0.4521737704918034, fairness violation: 0.004731763934426231, violated group size: 0.294
# iteration: 306, error: 0.45229738562091504, fairness violation: 0.004720339869281046, violated group size: 0.294
# iteration: 307, error: 0.45245276872964163, fairness violation: 0.004704964169381107, violated group size: 0.206
# iteration: 308, error: 0.4526071428571429, fairness violation: 0.0046896883116883115, violated group size: 0.206
# iteration: 309, error: 0.4527605177993528, fairness violation: 0.004674511326860843, violated group size: 0.294
# iteration: 310, error: 0.45291290322580635, fairness violation: 0.004659432258064517, violated group size: 0.294
# iteration: 311, error: 0.45306430868167197, fairness violation: 0.004644450160771706, violated group size: 0.294
# iteration: 312, error: 0.4532147435897437, fairness violation: 0.004629564102564103, violated group size: 0.206
# iteration: 313, error: 0.4533322683706069, fairness violation: 0.004618722044728435, violated group size: 0.206
# iteration: 314, error: 0.4534808917197452, fairness violation: 0.004604012738853506, violated group size: 0.294
# iteration: 315, error: 0.45362857142857144, fairness violation: 0.004589396825396826, violated group size: 0.206
# iteration: 316, error: 0.453743670886076, fairness violation: 0.0045787848101265845, violated group size: 0.294
# iteration: 317, error: 0.4538895899053629, fairness violation: 0.00456434069400631, violated group size: 0.206
# iteration: 318, error: 0.45400314465408803, fairness violation: 0.004553874213836478, violated group size: 0.294
# iteration: 319, error: 0.45414733542319746, fairness violation: 0.004539598746081506, violated group size: 0.294
# iteration: 320, error: 0.4542593749999999, fairness violation: 0.004529275, violated group size: 0.206
# iteration: 321, error: 0.45437071651090344, fairness violation: 0.004519015576323988, violated group size: 0.294
# iteration: 322, error: 0.45451242236024836, fairness violation: 0.004504981366459629, violated group size: 0.294
# iteration: 323, error: 0.4546222910216718, fairness violation: 0.004494860681114552, violated group size: 0.206
# iteration: 324, error: 0.4547623456790123, fairness violation: 0.004480987654320988, violated group size: 0.206
# iteration: 325, error: 0.4548707692307692, fairness violation: 0.004471003076923077, violated group size: 0.206
# iteration: 326, error: 0.454978527607362, fairness violation: 0.004461079754601227, violated group size: 0.206
# iteration: 327, error: 0.455085626911315, fairness violation: 0.004451217125382263, violated group size: 0.294
# iteration: 328, error: 0.4552225609756097, fairness violation: 0.004437646341463415, violated group size: 0.206
# iteration: 329, error: 0.4553282674772038, fairness violation: 0.004427914893617022, violated group size: 0.206
# iteration: 330, error: 0.4554333333333333, fairness violation: 0.004418242424242424, violated group size: 0.294
# iteration: 331, error: 0.4555377643504532, fairness violation: 0.004408628398791542, violated group size: 0.294
# iteration: 332, error: 0.45564156626506025, fairness violation: 0.004399072289156627, violated group size: 0.206
# iteration: 333, error: 0.4557447447447447, fairness violation: 0.004389573573573574, violated group size: 0.206
# iteration: 334, error: 0.4558473053892216, fairness violation: 0.004380131736526946, violated group size: 0.206
# iteration: 335, error: 0.4559492537313434, fairness violation: 0.0043707462686567175, violated group size: 0.294
# iteration: 336, error: 0.4560505952380952, fairness violation: 0.004361416666666668, violated group size: 0.294
# iteration: 337, error: 0.45615133531157276, fairness violation: 0.004352142433234421, violated group size: 0.206
# iteration: 338, error: 0.4562514792899408, fairness violation: 0.0043429230769230776, violated group size: 0.294
# iteration: 339, error: 0.45635103244837755, fairness violation: 0.0043337581120943955, violated group size: 0.294
# iteration: 340, error: 0.4564499999999999, fairness violation: 0.0043246470588235286, violated group size: 0.206
# iteration: 341, error: 0.4565483870967741, fairness violation: 0.0043155894428152505, violated group size: 0.294
# iteration: 342, error: 0.45664619883040936, fairness violation: 0.004306584795321638, violated group size: 0.206
# iteration: 343, error: 0.45674344023323615, fairness violation: 0.004297632653061226, violated group size: 0.294
# iteration: 344, error: 0.4568401162790699, fairness violation: 0.004288732558139535, violated group size: 0.206
# iteration: 345, error: 0.4567710144927537, fairness violation: 0.004294214492753623, violated group size: 0.206
# iteration: 346, error: 0.45686705202312133, fairness violation: 0.004285375722543352, violated group size: 0.206
# iteration: 347, error: 0.45696253602305464, fairness violation: 0.0042765878962536035, violated group size: 0.294
# iteration: 348, error: 0.45705747126436785, fairness violation: 0.004267850574712645, violated group size: 0.294
# iteration: 349, error: 0.4571518624641835, fairness violation: 0.004259163323782234, violated group size: 0.206
# iteration: 350, error: 0.4572457142857142, fairness violation: 0.004250525714285715, violated group size: 0.206
# iteration: 351, error: 0.45733903133903137, fairness violation: 0.004241937321937322, violated group size: 0.206
# iteration: 352, error: 0.45743181818181833, fairness violation: 0.004233397727272727, violated group size: 0.206
# iteration: 353, error: 0.45752407932011335, fairness violation: 0.0042249065155807375, violated group size: 0.294
# iteration: 354, error: 0.45761581920903954, fairness violation: 0.004216463276836158, violated group size: 0.206
# iteration: 355, error: 0.4577070422535211, fairness violation: 0.004208067605633802, violated group size: 0.206
# iteration: 356, error: 0.45779775280898877, fairness violation: 0.004199719101123596, violated group size: 0.206
# iteration: 357, error: 0.4577282913165266, fairness violation: 0.004205266106442578, violated group size: 0.294
# iteration: 358, error: 0.45774301675977647, fairness violation: 0.0042050279329608935, violated group size: 0.206
# iteration: 359, error: 0.45783286908078, fairness violation: 0.004196757660167131, violated group size: 0.206
# iteration: 360, error: 0.4579222222222222, fairness violation: 0.0041885333333333335, violated group size: 0.294
# iteration: 361, error: 0.45793628808864256, fairness violation: 0.0041883434903047115, violated group size: 0.294
# iteration: 362, error: 0.45802486187845315, fairness violation: 0.004180187845303868, violated group size: 0.294
# iteration: 363, error: 0.45788154269972453, fairness violation: 0.004193641873278237, violated group size: 0.294
# iteration: 364, error: 0.45796978021978024, fairness violation: 0.004185516483516484, violated group size: 0.294
# iteration: 365, error: 0.4579835616438357, fairness violation: 0.00418533698630137, violated group size: 0.294
# iteration: 366, error: 0.45784153005464484, fairness violation: 0.004198666666666667, violated group size: 0.294
# iteration: 367, error: 0.45777384196185283, fairness violation: 0.004204065395095367, violated group size: 0.206
# iteration: 368, error: 0.45770652173913046, fairness violation: 0.004209434782608697, violated group size: 0.294
# iteration: 369, error: 0.45756639566395674, fairness violation: 0.004222590785907859, violated group size: 0.206
# iteration: 370, error: 0.4574270270270271, fairness violation: 0.0042356756756756755, violated group size: 0.206
# iteration: 371, error: 0.45736118598382747, fairness violation: 0.0042409164420485175, violated group size: 0.294
# iteration: 372, error: 0.4572956989247312, fairness violation: 0.004246129032258065, violated group size: 0.294
# iteration: 373, error: 0.4572305630026809, fairness violation: 0.004251313672922252, violated group size: 0.294
# iteration: 374, error: 0.45716577540106956, fairness violation: 0.004256470588235295, violated group size: 0.294
# iteration: 375, error: 0.45710133333333336, fairness violation: 0.0042616, violated group size: 0.206
# iteration: 376, error: 0.4571888297872341, fairness violation: 0.004253553191489362, violated group size: 0.206
# iteration: 377, error: 0.4571246684350132, fairness violation: 0.004258663129973476, violated group size: 0.206
# iteration: 378, error: 0.45698941798941795, fairness violation: 0.004271375661375662, violated group size: 0.294
# iteration: 379, error: 0.45692612137203165, fairness violation: 0.00427641160949868, violated group size: 0.206
# iteration: 380, error: 0.45679210526315783, fairness violation: 0.004289010526315789, violated group size: 0.206
# iteration: 381, error: 0.4566587926509187, fairness violation: 0.004301543307086614, violated group size: 0.206
# iteration: 382, error: 0.45652617801047113, fairness violation: 0.004314010471204189, violated group size: 0.294
# iteration: 383, error: 0.4563942558746737, fairness violation: 0.004326412532637075, violated group size: 0.206
# iteration: 384, error: 0.4562630208333334, fairness violation: 0.004338750000000001, violated group size: 0.294
# iteration: 385, error: 0.45613246753246756, fairness violation: 0.0043510233766233765, violated group size: 0.206
# iteration: 386, error: 0.4560025906735751, fairness violation: 0.004363233160621763, violated group size: 0.294
# iteration: 387, error: 0.45587338501291996, fairness violation: 0.00437537984496124, violated group size: 0.294
# iteration: 388, error: 0.45574484536082455, fairness violation: 0.0043874639175257735, violated group size: 0.294
# iteration: 389, error: 0.45561696658097683, fairness violation: 0.004399485861182519, violated group size: 0.206
# iteration: 390, error: 0.4554897435897436, fairness violation: 0.004411446153846154, violated group size: 0.206
# iteration: 391, error: 0.45543222506393854, fairness violation: 0.004415969309462916, violated group size: 0.206
# iteration: 392, error: 0.45530612244897967, fairness violation: 0.004427826530612245, violated group size: 0.294
# iteration: 393, error: 0.45518066157760806, fairness violation: 0.004439623409669211, violated group size: 0.206
# iteration: 394, error: 0.45505583756345175, fairness violation: 0.004451360406091371, violated group size: 0.294
# iteration: 395, error: 0.45493164556962024, fairness violation: 0.004463037974683544, violated group size: 0.206
# iteration: 396, error: 0.45480808080808083, fairness violation: 0.004474656565656566, violated group size: 0.294
# iteration: 397, error: 0.4547531486146096, fairness violation: 0.004478952141057936, violated group size: 0.294
# iteration: 398, error: 0.4546306532663317, fairness violation: 0.004490472361809046, violated group size: 0.206
# iteration: 399, error: 0.4545087719298245, fairness violation: 0.004501934837092734, violated group size: 0.294
# iteration: 400, error: 0.45438750000000006, fairness violation: 0.004513340000000001, violated group size: 0.294
# iteration: 401, error: 0.4542668329177058, fairness violation: 0.0045246882793017465, violated group size: 0.206
# iteration: 402, error: 0.4541467661691543, fairness violation: 0.004535980099502488, violated group size: 0.206
# iteration: 403, error: 0.45402729528535984, fairness violation: 0.004547215880893302, violated group size: 0.294
# iteration: 404, error: 0.4539084158415841, fairness violation: 0.004558396039603962, violated group size: 0.294
# iteration: 405, error: 0.4537901234567901, fairness violation: 0.004569520987654322, violated group size: 0.206
# iteration: 406, error: 0.45367241379310347, fairness violation: 0.0045805911330049276, violated group size: 0.294
# iteration: 407, error: 0.4535552825552825, fairness violation: 0.00459160687960688, violated group size: 0.206
# iteration: 408, error: 0.4534387254901962, fairness violation: 0.004602568627450981, violated group size: 0.206
# iteration: 409, error: 0.45332273838630804, fairness violation: 0.004613476772616139, violated group size: 0.206
# iteration: 410, error: 0.4532073170731707, fairness violation: 0.0046243317073170745, violated group size: 0.206
# iteration: 411, error: 0.45309245742092447, fairness violation: 0.00463513381995134, violated group size: 0.206
# iteration: 412, error: 0.4529781553398058, fairness violation: 0.004645883495145632, violated group size: 0.206
# iteration: 413, error: 0.45286440677966106, fairness violation: 0.004656581113801454, violated group size: 0.294
# iteration: 414, error: 0.4527512077294684, fairness violation: 0.004667227053140099, violated group size: 0.294
# iteration: 415, error: 0.45263855421686744, fairness violation: 0.0046778216867469895, violated group size: 0.294
# iteration: 416, error: 0.4525264423076923, fairness violation: 0.004688365384615387, violated group size: 0.294
# iteration: 417, error: 0.4524148681055156, fairness violation: 0.00469885851318945, violated group size: 0.206
# iteration: 418, error: 0.45230382775119615, fairness violation: 0.0047093014354067, violated group size: 0.206
# iteration: 419, error: 0.4521933174224343, fairness violation: 0.004719694510739858, violated group size: 0.206
# iteration: 420, error: 0.4520833333333332, fairness violation: 0.004730038095238096, violated group size: 0.206
# iteration: 421, error: 0.45197387173396675, fairness violation: 0.004740332541567697, violated group size: 0.206
# iteration: 422, error: 0.45186492890995267, fairness violation: 0.004750578199052136, violated group size: 0.294
# iteration: 423, error: 0.45175650118203303, fairness violation: 0.004760775413711585, violated group size: 0.206
# iteration: 424, error: 0.45164858490566023, fairness violation: 0.004770924528301889, violated group size: 0.206
# iteration: 425, error: 0.45154117647058833, fairness violation: 0.004781025882352944, violated group size: 0.294
# iteration: 426, error: 0.45143427230046945, fairness violation: 0.004791079812206576, violated group size: 0.294
# iteration: 427, error: 0.45132786885245896, fairness violation: 0.004801086651053867, violated group size: 0.294
# iteration: 428, error: 0.45122196261682246, fairness violation: 0.004811046728971964, violated group size: 0.206
# iteration: 429, error: 0.45111655011655005, fairness violation: 0.004820960372960374, violated group size: 0.206
# iteration: 430, error: 0.4510116279069768, fairness violation: 0.004830827906976746, violated group size: 0.206
# iteration: 431, error: 0.4509071925754061, fairness violation: 0.00484064965197216, violated group size: 0.294
# iteration: 432, error: 0.4508032407407407, fairness violation: 0.004850425925925927, violated group size: 0.206
# iteration: 433, error: 0.4506997690531178, fairness violation: 0.004860157043879909, violated group size: 0.206
# iteration: 434, error: 0.4505967741935484, fairness violation: 0.004869843317972351, violated group size: 0.206
# iteration: 435, error: 0.4504942528735632, fairness violation: 0.004879485057471267, violated group size: 0.294
# iteration: 436, error: 0.4503922018348623, fairness violation: 0.00488908256880734, violated group size: 0.206
# iteration: 437, error: 0.4502906178489704, fairness violation: 0.004898636155606409, violated group size: 0.206
# iteration: 438, error: 0.4501894977168949, fairness violation: 0.004908146118721464, violated group size: 0.206
# iteration: 439, error: 0.45008883826879276, fairness violation: 0.004917612756264239, violated group size: 0.206
# iteration: 440, error: 0.44998863636363634, fairness violation: 0.004927036363636364, violated group size: 0.206
# iteration: 441, error: 0.4498888888888889, fairness violation: 0.004936417233560091, violated group size: 0.206
# iteration: 442, error: 0.449789592760181, fairness violation: 0.004945755656108597, violated group size: 0.206
# iteration: 443, error: 0.4496907449209931, fairness violation: 0.004955051918735893, violated group size: 0.294
# iteration: 444, error: 0.4495923423423424, fairness violation: 0.004964306306306307, violated group size: 0.206
# iteration: 445, error: 0.4494943820224719, fairness violation: 0.004973519101123598, violated group size: 0.294
# iteration: 446, error: 0.4493968609865471, fairness violation: 0.004982690582959641, violated group size: 0.206
# iteration: 447, error: 0.44929977628635337, fairness violation: 0.004991821029082775, violated group size: 0.206
# iteration: 448, error: 0.449203125, fairness violation: 0.005000910714285716, violated group size: 0.294
# iteration: 449, error: 0.44910690423162586, fairness violation: 0.005009959910913141, violated group size: 0.206
# iteration: 450, error: 0.449011111111111, fairness violation: 0.00501896888888889, violated group size: 0.206
# iteration: 451, error: 0.4489157427937916, fairness violation: 0.005027937915742795, violated group size: 0.206
# iteration: 452, error: 0.448820796460177, fairness violation: 0.0050368672566371685, violated group size: 0.206
# iteration: 453, error: 0.4487262693156734, fairness violation: 0.005045757174392938, violated group size: 0.206
# iteration: 454, error: 0.44869162995594714, fairness violation: 0.005048255506607931, violated group size: 0.294
# iteration: 455, error: 0.44859780219780215, fairness violation: 0.005057081318681319, violated group size: 0.206
# iteration: 456, error: 0.4485043859649123, fairness violation: 0.005065868421052632, violated group size: 0.206
# iteration: 457, error: 0.44841137855579866, fairness violation: 0.005688512035010943, violated group size: 0.239
# iteration: 458, error: 0.4483187772925764, fairness violation: 0.005699052401746726, violated group size: 0.261
# iteration: 459, error: 0.44828540305010894, fairness violation: 0.0057022570806100235, violated group size: 0.239
# iteration: 460, error: 0.4483760869565217, fairness violation: 0.005692978260869568, violated group size: 0.261
# iteration: 461, error: 0.4484663774403471, fairness violation: 0.005683739696312366, violated group size: 0.261
# iteration: 462, error: 0.448556277056277, fairness violation: 0.005674541125541128, violated group size: 0.239
# iteration: 463, error: 0.44864578833693297, fairness violation: 0.005665382289416848, violated group size: 0.239
# iteration: 464, error: 0.4487349137931033, fairness violation: 0.005656262931034486, violated group size: 0.261
# iteration: 465, error: 0.4488236559139785, fairness violation: 0.005647182795698929, violated group size: 0.261
# iteration: 466, error: 0.44891201716738205, fairness violation: 0.005638141630901291, violated group size: 0.261
# iteration: 467, error: 0.44899999999999995, fairness violation: 0.005629139186295503, violated group size: 0.261
# iteration: 468, error: 0.44910897435897434, fairness violation: 0.005617111111111112, violated group size: 0.261
# iteration: 469, error: 0.4491961620469084, fairness violation: 0.005608191897654586, violated group size: 0.261
# iteration: 470, error: 0.44930425531914897, fairness violation: 0.005596259574468085, violated group size: 0.239
# iteration: 471, error: 0.44941188959660305, fairness violation: 0.005584377919320596, violated group size: 0.261
# iteration: 472, error: 0.44949788135593227, fairness violation: 0.005575584745762712, violated group size: 0.239
# iteration: 473, error: 0.44960465116279086, fairness violation: 0.005563797040169133, violated group size: 0.239
# iteration: 474, error: 0.449710970464135, fairness violation: 0.0055520590717299595, violated group size: 0.239
# iteration: 475, error: 0.4498168421052633, fairness violation: 0.005540370526315791, violated group size: 0.239
# iteration: 476, error: 0.44992226890756315, fairness violation: 0.005528731092436975, violated group size: 0.261
# iteration: 477, error: 0.4500272536687631, fairness violation: 0.005517140461215934, violated group size: 0.261
# iteration: 478, error: 0.45013179916317997, fairness violation: 0.005505598326359834, violated group size: 0.261
# iteration: 479, error: 0.45023590814196246, fairness violation: 0.0054941043841336135, violated group size: 0.239
# iteration: 480, error: 0.45033958333333335, fairness violation: 0.005482658333333335, violated group size: 0.261
# iteration: 481, error: 0.4504428274428275, fairness violation: 0.0054712598752598785, violated group size: 0.261
# iteration: 482, error: 0.45054564315352696, fairness violation: 0.005459908713692949, violated group size: 0.261
# iteration: 483, error: 0.4506480331262941, fairness violation: 0.005448604554865425, violated group size: 0.239
# iteration: 484, error: 0.45074999999999993, fairness violation: 0.005437347107438019, violated group size: 0.261
# iteration: 485, error: 0.45085154639175257, fairness violation: 0.005426136082474228, violated group size: 0.261
# iteration: 486, error: 0.4509526748971194, fairness violation: 0.0054149711934156405, violated group size: 0.261
# iteration: 487, error: 0.451053388090349, fairness violation: 0.005403852156057496, violated group size: 0.239
# iteration: 488, error: 0.45115368852459004, fairness violation: 0.005392778688524593, violated group size: 0.261
# iteration: 489, error: 0.4512535787321064, fairness violation: 0.005381750511247445, violated group size: 0.239
# iteration: 490, error: 0.45135306122448976, fairness violation: 0.005370767346938778, violated group size: 0.261
# iteration: 491, error: 0.4514521384928716, fairness violation: 0.005359828920570268, violated group size: 0.261
# iteration: 492, error: 0.4515508130081301, fairness violation: 0.005348934959349595, violated group size: 0.239
# iteration: 493, error: 0.4516490872210953, fairness violation: 0.00533808519269777, violated group size: 0.261
# iteration: 494, error: 0.4517469635627529, fairness violation: 0.005327279352226724, violated group size: 0.261
# iteration: 495, error: 0.4518444444444445, fairness violation: 0.005316517171717174, violated group size: 0.261
# iteration: 496, error: 0.4519415322580645, fairness violation: 0.005305798387096777, violated group size: 0.261
# iteration: 497, error: 0.4520382293762575, fairness violation: 0.005295122736418512, violated group size: 0.239
# iteration: 498, error: 0.45213453815261034, fairness violation: 0.005284489959839359, violated group size: 0.239
# iteration: 499, error: 0.4522304609218437, fairness violation: 0.005273899799599201, violated group size: 0.261

# %% [markdown]
# **3-d heatmaps**
#
# We now show to generate a 3d-heatmap of unfairness using the `generate_heatmap` method. The $X-Y$ axes in the plot represent the coefficients of the linear threshold function that defines a protected subgroup with respect to the first two sensitive attributes. Which $2$ attributes are considered sensitive can be overwritten with the `col_index` argument. The $Z$-axes is the $\gamma$-disparity (FP) of the corresponding subgroup defined by the linear threshold function. This is important because it allows us to (1) visualize convergence as the heatmap flattens and (2) brute force check the fairness in low-dimensions without relying on a heuristic auditor. See the [the rich subgroup fairness empirical paper](https://arxiv.org/abs/1808.08166) for a discussion of these plots. Note that in the below plot no group has a $\gamma$-disparity of greater than $.005$, which we would expect since the set of linear threshold functions on two attributes is a subset of the set of linear threshold functions on all protected attributes, and the final model is $\gamma$-fair.

# %%
# output heatmap (brute force)
# replace None with the relative path if you want to save the plot
fair_model.heatmapflag = True
fair_model.heatmap_path  = 'heatmap'
fair_model.generate_heatmap(data_set, dataset_yhat.labels)
Image(filename='{}.png'.format(fair_model.heatmap_path))

# %% [markdown]
# **black-box auditing**
#
# We now show to audit any black box classifier with respect to rich subgroup fairness under either FP or FN rate. Note the below auditing procedure would work for any set of (soft) predictions $\hat{y}$, and need make no assumptions about the structure of the predictor. We note that as expected the disparity of the group found is the same as the disparity printed out in the last iteration of the `fit` method.

# %%
gerry_metric = BinaryLabelDatasetMetric(data_set)
gamma_disparity = gerry_metric.rich_subgroup(array_to_tuple(dataset_yhat.labels), 'FP')
print(gamma_disparity)
# Out:
# 0.005273899799599204

# %% [markdown]
# **pareto curves**
#
# The `FairFictPlay` algorithm implemented in the `fit` method converges given access to perfect oracles for solving cost-sensitive classification (CSC) problems. A cost-sensitive classification problem over a hypothesis class $\mathcal{H}$ is $$\min_{h}\sum_{i = 1}^{n}(1-h(x_i))c_0 + h(x_i)c_1$$
# By default in this package, and in the companion [empirical](https://arxiv.org/abs/1808.08166) and [theory](https://arxiv.org/pdf/1711.05144.pdf) papers, the hypothesis class of the learner and the of the subgroups are hyperplanes. The corresponding heuristic oracle for solving the CSC problem first forms two regression problems $(x_i, c_0)$ and $(x_i, c_1)$. Then in the case of hyperplanes, trains two regressions $r_i: \mathcal{X} \to R$ which predict the costs of classifying a given point $x$ $0,1$ respectively. Finally the binary classifier output by the oracle is defined as $\hat{r}(x) = \arg\min_{j \in \{0,1\}}r_j(x)$. But of course if we are interesting in different hypothesis classes for the learner, we simply need different regressors. In this package in addition to linear regression, we've added support for regression trees, kernelized ridge regression, and support vector regression. Below we trace out Pareto curves of $\gamma$-disparity vs. error for each of these different heuristic oracles.

# %%
# set to 50 iterations for fast running of notebook - set >= 1000 when running real experiments
pareto_iters = 50
def multiple_classifiers_pareto(dataset, gamma_list=[0.002, 0.005, 0.01, 0.02, 0.05, 0.1], save_results=False, iters=pareto_iters):

    ln_predictor = linear_model.LinearRegression()
    svm_predictor = svm.LinearSVR()
    tree_predictor = tree.DecisionTreeRegressor(max_depth=3)
    kernel_predictor = KernelRidge(alpha=1.0, gamma=1.0, kernel='rbf')
    predictor_dict = {'Linear': {'predictor': ln_predictor, 'iters': iters},
                      'SVR': {'predictor': svm_predictor, 'iters': iters},
                      'Tree': {'predictor': tree_predictor, 'iters': iters},
                      'Kernel': {'predictor': kernel_predictor, 'iters': iters}}

    results_dict = {}

    for pred in predictor_dict:
        print('Curr Predictor: {}'.format(pred))
        predictor = predictor_dict[pred]['predictor']
        max_iters = predictor_dict[pred]['iters']
        fair_clf = GerryFairClassifier(C=100, printflag=True, gamma=1, predictor=predictor, max_iters=max_iters)
        fair_clf.printflag = False
        fair_clf.max_iters=max_iters
        errors, fp_violations, fn_violations = fair_clf.pareto(dataset, gamma_list)
        results_dict[pred] = {'errors': errors, 'fp_violations': fp_violations, 'fn_violations': fn_violations}
        plt.plot(errors, fp_violations, label=pred)

    if save_results:
        pickle.dump(results_dict, open('results_dict_' + str(gamma_list) + '_gammas' + str(gamma_list) + '.pkl', 'wb'))

    plt.xlabel('Error')
    plt.ylabel('Unfairness')
    plt.legend()
    plt.title('Error vs. Unfairness\n(Adult Dataset)')
    plt.savefig('gerryfair_pareto.png')
    plt.close()
multiple_classifiers_pareto(data_set)
Image(filename='gerryfair_pareto.png')
# Out:
# Curr Predictor: Linear
# Curr Predictor: SVR
# Curr Predictor: Tree
# Curr Predictor: Kernel

# %% [markdown]
# A natural question one might ask is, suppose we fix a statistical fairness definition for rich subgroup fairness like equality of false positive rates, `FP`. Does learning a classifier that is fair with respect to `FP` increase or decrease fairness with respect to false negative rates `FN`? One could see this relationship going in either direction - and indeed we submit that it is dataset dependent. In some cases, if enforcing `FP` fairness pushes the classifier towards the constant classifier, then it will also satisify `FN` rate fairness, since the constant classifier is perfectly fair. However, if the hypothesis class is sufficiently rich, then one would expect that ceteris paribus since we are optimizing for error in addition to `FP` rate fairness, the algorithm would increase `FN` rate unfairness in order to decrease error. Below we trace the FN vs. FP rate tradeoff across a range of input $\gamma$, where the classifier is optimized only for `FP` rate fairness.

# %%
def fp_vs_fn(dataset, gamma_list, iters):
    fp_auditor = Auditor(dataset, 'FP')
    fn_auditor = Auditor(dataset, 'FN')
    fp_violations = []
    fn_violations = []
    for g in gamma_list:
        print('gamma: {} '.format(g), end =" ")
        fair_model = GerryFairClassifier(C=100, printflag=False, gamma=g, max_iters=iters)
        fair_model.gamma=g
        fair_model.fit(dataset)
        predictions = array_to_tuple((fair_model.predict(dataset)).labels)
        _, fp_diff = fp_auditor.audit(predictions)
        _, fn_diff = fn_auditor.audit(predictions)
        fp_violations.append(fp_diff)
        fn_violations.append(fn_diff)

    plt.plot(fp_violations, fn_violations, label='adult')
    plt.xlabel('False Positive Disparity')
    plt.ylabel('False Negative Disparity')
    plt.legend()
    plt.title('FP vs FN Unfairness')
    plt.savefig('gerryfair_fp_fn.png')
    plt.close()

gamma_list = [0.001, 0.002, 0.003, 0.004, 0.005, 0.0075, 0.01, 0.02, 0.03, 0.05]
fp_vs_fn(data_set, gamma_list, pareto_iters)
Image(filename='gerryfair_fp_fn.png')
# Out:
# gamma: 0.001  gamma: 0.002  gamma: 0.003  gamma: 0.004  gamma: 0.005  gamma: 0.0075  gamma: 0.01  gamma: 0.02  gamma: 0.03  gamma: 0.05
